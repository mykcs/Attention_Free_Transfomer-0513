# %% [markdown]
# <a href="https://colab.research.google.com/github/mykcs/Attention_Free_Transfomer-0513/blob/main/RWKV_first_try_20240513.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/BlinkDL/RWKV-LM.git
#!wget https://huggingface.co/BlinkDL/rwkv-4-pile-3b/resolve/main/RWKV-4-Pile-3B-20220915-1207.pth -O ./RWKV-LM/RWKV-v4/500.pth 3B needs more vram then google offers
# !wget https://huggingface.co/BlinkDL/rwkv-4-pile-1b5/resolve/main/RWKV-4-Pile-1B5-20220903-8040.pth -O ./RWKV-LM/RWKV-v4/500.pth
# Out:
# Cloning into 'RWKV-LM'...
# remote: Enumerating objects: 2367, done.
# remote: Counting objects: 100% (857/857), done.
# remote: Compressing objects: 100% (242/242), done.
# remote: Total 2367 (delta 758), reused 658 (delta 613), pack-reused 1510
# Receiving objects: 100% (2367/2367), 17.66 MiB | 25.04 MiB/s, done.
# Resolving deltas: 100% (1531/1531), done.
# --2024-05-12 17:01:34--  https://huggingface.co/BlinkDL/rwkv-4-pile-1b5/resolve/main/RWKV-4-Pile-1B5-20220903-8040.pth
# Resolving huggingface.co (huggingface.co)... 18.172.134.4, 18.172.134.88, 18.172.134.124, ...
# Connecting to huggingface.co (huggingface.co)|18.172.134.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/d6/95/d69583b06567422d104d5413e7926ae97bcf0d541619db6e61fe10133d91582d/4e215be3b4f86dc2f145835b47a2c432306c373cbf625375b7721bb474512bad?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27RWKV-4-Pile-1B5-20220903-8040.pth%3B+filename%3D%22RWKV-4-Pile-1B5-20220903-8040.pth%22%3B&Expires=1715792495&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=NrW5kuAIxXh1exZv1UYmlDDg7R27vuxkhyam70oh3OLmLirnDA6bqID4cvYBHH06GMC9EYKUrAyAoccA%7EYGPZ1cLZ7wNhL1DlzzzWTZDOR%7EY4OTgpyusFZ0wcxpbAE2NroEg9Jm7ADoBmN%7EWY-FWIPnbXXDLkbE9UZi3d4g0B0u6X8eMqfoEZtW-wsBcM8t8x6w7lL6M-b%7E8ujvbHQBo58%7EGNPzNLB3e2uE0vURVJ28B7-9E-vaDCtclXKLzvlLBuxqQ5Ilwj5x4VcENlR-xXIIcGhdtoDiAJRG-TWtGuopRwwaUfFzBx5VFQ4KLTLsGNxKDmyRgyK6VY-8U1FsmLw__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2024-05-12 17:01:35--  https://cdn-lfs.huggingface.co/repos/d6/95/d69583b06567422d104d5413e7926ae97bcf0d541619db6e61fe10133d91582d/4e215be3b4f86dc2f145835b47a2c432306c373cbf625375b7721bb474512bad?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27RWKV-4-Pile-1B5-20220903-8040.pth%3B+filename%3D%22RWKV-4-Pile-1B5-20220903-8040.pth%22%3B&Expires=1715792495&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=NrW5kuAIxXh1exZv1UYmlDDg7R27vuxkhyam70oh3OLmLirnDA6bqID4cvYBHH06GMC9EYKUrAyAoccA%7EYGPZ1cLZ7wNhL1DlzzzWTZDOR%7EY4OTgpyusFZ0wcxpbAE2NroEg9Jm7ADoBmN%7EWY-FWIPnbXXDLkbE9UZi3d4g0B0u6X8eMqfoEZtW-wsBcM8t8x6w7lL6M-b%7E8ujvbHQBo58%7EGNPzNLB3e2uE0vURVJ28B7-9E-vaDCtclXKLzvlLBuxqQ5Ilwj5x4VcENlR-xXIIcGhdtoDiAJRG-TWtGuopRwwaUfFzBx5VFQ4KLTLsGNxKDmyRgyK6VY-8U1FsmLw__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.154.185.64, 18.154.185.27, 18.154.185.26, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.154.185.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3030279587 (2.8G) [application/zip]
# Saving to: ‘./RWKV-LM/RWKV-v4/500.pth’
#
# ./RWKV-LM/RWKV-v4/5 100%[===================>]   2.82G  44.0MB/s    in 58s
#
# 2024-05-12 17:02:33 (50.1 MB/s) - ‘./RWKV-LM/RWKV-v4/500.pth’ saved [3030279587/3030279587]

# %%
# %cd ./RWKV-LM/RWKV-v4/
# Out:
# /content/RWKV-LM/RWKV-v4

# %%
# !pip install transformers
# !pip install ninja
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Collecting ninja
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: ninja
# Successfully installed ninja-1.11.1.1

# %%
########################################################################################################
# The RWKV Language Model - https://github.com/BlinkDL/RWKV-LM
########################################################################################################
import numpy as np
import math, os
import time
import types
import copy
import torch
from torch.nn import functional as F
from src.utils import TOKENIZER, Dataset
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.allow_tf32 = True
torch.backends.cuda.matmul.allow_tf32 = True
np.set_printoptions(precision=4, suppress=True, linewidth=200)

########################################################################################################
# Step 1: set model
#
# Set TOKEN_MODE to 'char' or 'bpe' if the model is trained by 'train.py' from scratch.
#
# Set TOKEN_MODE to 'pile' if you want to test pre-trained pile models.
########################################################################################################

TOKEN_MODE = 'pile' # char / bpe / pile

n_layer = 6
n_embd = 512
ctx_len = 10024

if TOKEN_MODE == 'char':
    MODEL_NAME = 'trained-500'  # your trained model
    WORD_NAME = 'vocab'         # the .json vocab (generated by train.py)
    # set UNKNOWN_CHAR to the rarest token in your vocab.json, and all unknown tokens in your prompt will be denoted by it
    UNKNOWN_CHAR = ' '          # here we just set it to ' ' for simplicity

elif TOKEN_MODE == 'bpe':
    MODEL_NAME = 'trained-500'  # your trained model
    WORD_NAME = ['model-vocab.json', 'model-merges.txt'] # [vocab, merge] for your BPE model
    UNKNOWN_CHAR = None

elif TOKEN_MODE == 'pile':
    WORD_NAME = ['20B_tokenizer.json', '20B_tokenizer.json']
    UNKNOWN_CHAR = None

    #---> you can set MODEL_NAME to your fine-tuned model <---

    MODEL_NAME = '500'

    # for 3b
    #n_layer = 32
    #n_embd = 2560
    #ctx_len = 10024

    # for 1b5'
    n_layer = 24
    n_embd = 2048
    ctx_len = 1024

os.environ['RWKV_FLOAT_MODE'] = 'bf16'  # 'bf16' / 'fp16' / 'fp32' (note: only using fp32 at this moment)
os.environ['RWKV_RUN_DEVICE'] = 'cuda'   # 'cpu' (already very fast) or 'cuda'
model_type = 'RWKV' # 'RWKV' or 'RWKV-ffnPre'

########################################################################################################
# Step 2: set prompt & sampling stuffs
########################################################################################################

# context = 'A'
# context = "\nIn the"
# context = '\nSugar:'

NUM_TRIALS = 5
LENGTH_PER_TRIAL = 3330

DEBUG_DEBUG = False  # True False --> show softmax output

########################################################################################################

print(f'Loading {MODEL_NAME}...')
from src.model_run import RWKV_RNN
model = RWKV_RNN(MODEL_NAME, os.environ['RWKV_RUN_DEVICE'], model_type, n_layer, n_embd, ctx_len)
tokenizer = TOKENIZER(WORD_NAME, UNKNOWN_CHAR=UNKNOWN_CHAR)
# Out:
# Loading 500...
#
# RWKV_HEAD_QK_DIM 0
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py310_cu121/wkv...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu121/wkv/build.ninja...
# Building extension module wkv...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Loading extension module wkv...

# %%
# !nvidia-smi
# Out:
# Sun May 12 17:03:18 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P0              30W /  70W |   8793MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
########################################################################################################
context = "You are an AI running a house.\ngiven the following commands: volumeUp(int amount),volumeDown(int amount),setVolume(int percent),setLights([r,g,b]),playSong(string url)\nand the given instruction 'Please make the room romantic'\nList the commands, and the parameters they should have, that should be done to fullfil the command\nGive the commands in the format [command(parameter)]\n\nTask: list the commands and a reasonable value for the parameter\nResponse:"

TEMPERATURE = 0.9
top_p = 0.8
top_p_newline = 0.9 # only used in TOKEN_MODE = char

if tokenizer.charMode:
    context = tokenizer.refine_context(context)
    ctx = [tokenizer.stoi.get(s, tokenizer.UNKNOWN_CHAR) for s in context]
else:
    ctx = tokenizer.tokenizer.encode(context)
src_len = len(ctx)
src_ctx = ctx.copy()

print('\nYour prompt has ' + str(src_len) + ' tokens.')
print('\n--> Currently the first run takes a while if your prompt is long, as we are using RNN to process the prompt. Use GPT to build the hidden state for better speed. <--\n')

for TRIAL in range(1 if DEBUG_DEBUG else NUM_TRIALS):
    t_begin = time.time_ns()
    print(('-' * 30) + context, end='')
    ctx = src_ctx.copy()
    model.clear()
    if TRIAL == 0:
        init_state = types.SimpleNamespace()
        for i in range(src_len):
            x = ctx[:i+1]
            if i == src_len - 1:
                init_state.out = model.run(x)
            else:
                model.run(x)
        model.save(init_state)
    else:
        model.load(init_state)

    for i in range(src_len, src_len + (1 if DEBUG_DEBUG else LENGTH_PER_TRIAL)):
        x = ctx[:i+1]
        x = x[-ctx_len:]

        if i == src_len:
            out = copy.deepcopy(init_state.out)
        else:
            out = model.run(x)
        if DEBUG_DEBUG:
            print('model', np.array(x), '==>', np.array(
                out), np.max(out), np.min(out))

        if TOKEN_MODE == 'pile':
            out[0] = -999999999  # disable <|endoftext|>

        char = tokenizer.sample_logits(out, x, ctx_len, temperature=TEMPERATURE,
                                       top_p_usual=top_p, top_p_newline=top_p_newline)
        char = char.item()
        if tokenizer.charMode:
            print(tokenizer.itos[int(char)], end='', flush=True)
        else:
            print(tokenizer.tokenizer.decode(int(char)), end='', flush=True)
        ctx += [char]

    t_end = time.time_ns()
    print("\n----------", round((t_end - t_begin) / (10 ** 9), 2), end='s ')
# Out:
# Your prompt has 110 tokens.
#
# --> Currently the first run takes a while if your prompt is long, as we are using RNN to process the prompt. Use GPT to build the hidden state for better speed. <--
#
# ------------------------------You are an AI running a house.
# given the following commands: volumeUp(int amount),volumeDown(int amount),setVolume(int percent),setLights([r,g,b]),playSong(string url)
# and the given instruction 'Please make the room romantic'
# List the commands, and the parameters they should have, that should be done to fullfil the command
# Give the commands in the format [command(parameter)]
#
# Task: list the commands and a reasonable value for the parameter
# Response:
# response: [2, "Please make the room romantic"]
#
# My code:
# #include<stdio.h>
# #include<string.h>
# #include<stdlib.h>
# #include<math.h>
#
# int main()
# {
#     int number;
#     char instruction[100];
#     int volumeUp, volumeDown, setVolume, r, g, b;
#     char command[100];
#
#     int i;
#     int n;
#
#     printf("Please make the room romantic\n");
#
#     //this should be the line i should write to have the command line on the right
#     printf("Please make the room romantic\n");
#
#     //check for user input
#     while (1)
#     {
#         //get a random number between 1-100
#         n=random(1,100);
#
#         //get the instruction
#         if(strcmp(instruction,"make the room romantic")==0)
#         {
#             r=random(10);
#             g=random(10);
#             b=random(10);
#             printf("Give the room a romantic name\n");
#             printf("Make the room romantic with: %d%%\n",r);
#             printf("Give the room romantic name with: %d%%\n",g);
#             printf("Make the room romantic with: %d%%\n",b);
#             printf("Give the room romantic name with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Give the room romantic name\n");
#             printf("Please make the room romantic with: %d%%\n",i);
#             printf("Please make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Give the room romantic name\n");
#             printf("Please make the room romantic with: %d%%\n",i);
#             printf("Give the room romantic name with: %d%%\n",i);
#             printf("Give the room romantic name with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n",i);
#             printf("Make the room romantic with: %d%%\n, and the volume
#             vol
#             volumes is the amount and the volume is the room.
#             i have full light installed
#             volume up and the number room up
#             volition
#             Room
#             room is the room in the following room
#         and the room is empty.
#         volist
#
#         Please take some time to find out.
#         I will run the command to do nothing else to be the room.
#         }
#         }
#     }
#     }
#     }
#         }
#         }
#     }
#     }
#     }
#     }
#     }
#     }
#     else if (strcmp(instruction,"make the room romantic with: %d")==0)
#     {
#         printf("Make the room romantic with: %d%%\n",i)
#         printf("Make the room romantic with: %d%%\n",i)
#         {
#             printf("Make the room romantic with: %d%%\n",i)
#             {
#             printf("Make the room romantic with: %d%%\n",i)
#             printf("Make the room romantic with: %d%%\n",i)
#             {
#                 printf("Make the room romantic with: %d%%\n",i)
#             {
#             printf("make the room romantic with: %d%%\n",i)
#             {
#             printf("Set volume to 100% to 0%")
#             {
#                 printf("Music is off the screen"} {
#                 "make the room romantic with: %d%% to be the room to the room" }
#                 {
#                     printf("You are an AI on the room")
#             }
#             {
#             volume up the amount of volume for this room to be 100%, please don't be impatient, and explain yourself", "%}
#             }
#             exit(0)
#             {
#             printf("Input error, please fix this room")
#             {
#                 "
#                 }
#             }
#             {
#                 "it"
#             }
#             else if you enjoy this. Please type the command in the next line: }
#         }
#         }
#         else if else please follow this command
#         }
#     }
#         }
#     }
#     }
#     }
#     }
#     }
#     }
#     else
#     {
#         printf("Please make the room romantic with: %d%% is off the list\n", number);
#         }
#         {
#             printf("Make the room romantic with: %d%% is the room\n", number)
#             {
#             " %\n"} %
#             "please\n")
#         {
#             printf("You are an artist\n\n"
#             "Thank you for your time in the last moments and i have got the room to find the time with been!!"
#             }
#             }
#             {"       "}
#             {"room is empty} {} and is the room
#             {"You are an room, and don't let anything happen with this time on the day. [l]"}
#         }
#         {
#             }
#             }
#         }
#         }
#         }
#         }
#         }
#         }
#         }
#         }
#         }
#     }
#     }
#     }
#     }
#     }
#     }
#     }
# }
#
# }
#
# }
#
# }
#
# This is not an assignment, so don't complain about this being a case of abuse, its just another code to make this easier to understand, its the only thing I want to help solve a problem for a class.
#
# I am a code developer and a beginner.
#
# A:
#
# Use const as you say you are a beginner and don't want to be a drudge or do something that is confusing or not as simple as possible. I understand when you say it's a bash and you know what I mean.
#
# A:
#
# I am unable to do this with the given commands.
#
# if i make the command as set volume up to 100 % for the last command with the instruction given then it is giving me a wrong output as you can see in the output in the image. If I use the instruction i.e. if I give the set volume command then it should not say 2% and if i make the room light then it should make the room romantic with the amount of time for each command.
#
# then please make my code as if I type make the room romantic with the instruction 1
#
# What do I have to do to achieve this task. I mean I am not sure how to do this. I don't know the other commands.
#
# A:
#
# I am a bot and I am NOT intelligent. What's the best way to fix this problem?
#
# A:
#
# Use the following code to generate a random command:
# for(i=0; i<n; i++)
# {
#     if(strrchr(instruction[i], ' ')==NULL)
#     {
#         printf("%s %s",command[i], setVolume(volume) + volume);
#         printf("This command is not possible in that case.\n\n");
#     }
# }
#     else if(strcmp(instruction[i], "setvolume")==0)
#     {
#         printf("Do you
# ---------- 164.42s ------------------------------You are an AI running a house.
# given the following commands: volumeUp(int amount),volumeDown(int amount),setVolume(int percent),setLights([r,g,b]),playSong(string url)
# and the given instruction 'Please make the room romantic'
# List the commands, and the parameters they should have, that should be done to fullfil the command
# Give the commands in the format [command(parameter)]
#
# Task: list the commands and a reasonable value for the parameter
# Response: number of seconds the command has been executed
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: list the commands and the parameters they should have, and the given instruction
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: Volume Up/Down
# Task: number of actions
# Task: humanise the following command
#
# Task: do a good job and much more
#
# What are the commands, and the parameters they should have, and the given instruction
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number of actions
# Task: number
# ---------- 153.17s ------------------------------You are an AI running a house.
# given the following commands: volumeUp(int amount),volumeDown(int amount),setVolume(int percent),setLights([r,g,b]),playSong(string url)
# and the given instruction 'Please make the room romantic'
# List the commands, and the parameters they should have, that should be done to fullfil the command
# Give the commands in the format [command(parameter)]
#
# Task: list the commands and a reasonable value for the parameter
# Response: 5.6
#
# A:
#
# I guess you want to try this yourself.  Here is a hint.  I have the code to do this.  It is from http://www.youtube.com/watch?v=oVvixI3yG7I&feature=player_embedded
# import java.util.ArrayList;
# import java.util.List;
#
# public class Robot {
#     private String name;
#     private int height;
#     private int weight;
#     private String skin;
#     private String eyes;
#     private int heightKilometer;
#     private int depthKilometer;
#     private String voice;
#     private int speechSpeed;
#     private String lips;
#     private int lipsVolume;
#     private int lungs;
#     private int lungsVolume;
#     private String eyeColor;
#     private int skinColor;
#     private int eyesColor;
#     private int skinColorColor;
#     private int lungsColorColor;
#     private int lungsColorDepth;
#     private String skinColorColor;
#     private int skinColorDepth;
#     private String eyesColor;
#     private int eyesColorDepth;
#     private String lungsColor;
#     private int lungsColorDepth;
#     private String lipsColor;
#     private int lipsColorDepth;
#     private String lipsColorColor;
#     private int lipsColorDepth;
#     private String lipsColorColor;
#     private int lipsColorDepth;
#     private String lipsColorColor;
#     private int lipsColorDepth;
#     private int eyesHeight;
#     private int eyesDepth;
#     private String eyesColor;
#     private int eyesDepth;
#     private String eyesColor;
#     private int eyesDepth;
#     private String eyesColor;
#     private int eyesDepth;
#     private String eyesColor;
#     private int eyesDepth;
#     private String eyesColor;
#     private int eyesDepth;
#     private String eyesColor;
#     private int eyesDepth;
#     private String eyesColor;
#     private int eyesDepth;
#     private String eyesColor;
#     private int eyesDepth;
#     private String lips;
#     private int lipsVolume;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth;
#     private String lipsColor;
#     private int lipsDepth
# ---------- 154.22s ------------------------------You are an AI running a house.
# given the following commands: volumeUp(int amount),volumeDown(int amount),setVolume(int percent),setLights([r,g,b]),playSong(string url)
# and the given instruction 'Please make the room romantic'
# List the commands, and the parameters they should have, that should be done to fullfil the command
# Give the commands in the format [command(parameter)]
#
# Task: list the commands and a reasonable value for the parameter
# Response: list the commands and the amount of each command
# Hint: the first command in the list should be the one that do not depend on any parameter.
#
# A:
#
# Here is the complete code.
# #include <iostream>
# #include <algorithm>
# #include <functional>
# #include <iterator>
# #include <vector>
#
# int main() {
#     std::vector<int> commands;
#
#     commands.push_back(10);
#     commands.push_back(20);
#     commands.push_back(30);
#     commands.push_back(40);
#     commands.push_back(50);
#     commands.push_back(60);
#
#     std::cout << "Actions: ";
#
#     for (auto cmd : commands) {
#         std::cout << " " << cmd;
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeUp(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeUp") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeUp(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeUp") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeUp(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeUp") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeUp(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeUp") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeUp(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeUp") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeUp(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeUp") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeUp(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeUp") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeUp(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeUp") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeUp(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeUp") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeUp(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeUp") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
# ...
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeUp(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeUp(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeUp(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeUp(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeUp(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
#
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount): ";
#     for (auto &cmd : commands) {
#         if (cmd.first == "VolumeDown") {
#             std::cout << cmd.second << std::endl;
#         }
#     }
# }
#
# And here is the output:
# Room::Room() :
#     std::cout << "Created" << std::endl;
#
#     setVolume(1);
#     std::cout << "Room::VolumeUp(int amount):";
#     setVolume(1);
#     std::cout << "Room::VolumeDown(int amount):";
#     setVolume(0);
#     std::cout << "Room::VolumeDown(int amount):";
#     setVolume(0);
#     std::cout << "Room::VolumeDown(int amount):";
#     setVolume(0);
#     std::cout << "VolumeDown(int amount):";
#     setVolume(0);
#     std::cout << "Room::VolumeUp(int amount):";
#     setVolume(1);
#     std::cout << "VolumeUp(int amount):";
#     setVolume(0);
#     std::cout << std::endl;
#     return 0;
# }
#
# VolumeUp()
#
# Command:
#     Room::VolumeDown(int amount):
#     std::cout << "Room::VolumeDown(int amount):";
#     setVolume(0);
#     std::cout << "VolumeDown(int amount):";
#     setVolume(1);
#     std::cout << "Room::VolumeUp(int amount):";
#     setVolume(1);
#     std::cout << "VolumeUp(int amount):";
#     setVolume(0);
#     std::cout << std::endl;
#
#     std::cout << "Room::VolumeDown(int amount):";
#     setVolume(0);
#     std::cout << "VolumeDown(int amount):";
#     setVolume(0);
#     std::cout << std::endl;
#     return 0;
# }
#
# Output:
#
# Room::VolumeDown(int amount):
#     Action(1)
#     VolumeDown(int amount):
#         Room::VolumeDown(int amount):
#             5
#             Command(int,int)
#                 Room::Room(std::vector<int> volume,int volume,int);
#
# VolumeUp(int)
#             Room::Room():
#             Room::VolumeUp(int,int),VolumeUp(int,0)
#             Room::VolumeDown(int),VolumeDown(1)
#             VolumeDown(int)
#             Room::VolumeDown(int,int)
#             Room::Room()
#
# Please see the following
#
# Room::Room() : Error: copy constructor
#     Room::Room(const Room&)
#         :
#         std::ostream(std::cerr)
#             ^
#             __tgt::
#                            __t.
#                              Test::Action::Room::VolumeUp
#                                    ^
#
# Command:
#
#     Room::Room():
#         Room::Room():
#         std::string( "Room::", "?")
#             ^
#             "Room::VolumeUp(int, int)",
#             1
#
# cmd.run(0, 10, 5, "Press the up arrow key to play");
#     ^
#     (0x00007ffff751020)
#     int main(void) {
#     ^
#     main() at 0x5b68b49
#
# {
#         ^
#     Command(int, int):
#     VolumeUp(0, 0)
#         Room::VolumeUp(int, int)
#             ^
#             __r
#     ^
#     (
#         1
#     )
#     ;
# }
#
# A:
#
# After I posted this question I checked the function of the library, and it was just enough to add a while loop after each command.
#
#     for (auto& room : rooms) {
#         for (auto cmd : room::Command) {
#             if (cmd.first == "Room::VolumeUp") {
#                 if (volumeUp(cmd.first)) {
#                     std::cout << "Added!" << std::endl;
#                 }
#                 setVolume(volumeUp(cmd.second));
#             }
#             }
#         }
#         }
#     }
#     }
#
#     }
#     return 0;
# }
#
#
# ---------- 152.61s ------------------------------You are an AI running a house.
# given the following commands: volumeUp(int amount),volumeDown(int amount),setVolume(int percent),setLights([r,g,b]),playSong(string url)
# and the given instruction 'Please make the room romantic'
# List the commands, and the parameters they should have, that should be done to fullfil the command
# Give the commands in the format [command(parameter)]
#
# Task: list the commands and a reasonable value for the parameter
# Response:
#
# the command should be something that means (but not limited to) what the user wants to do. In my case I would be playing a song.
#
# A:
#
# 1. Adding the sounds to the playlist:
# Here is a simple script I put together that you can run to add the sounds to the playlist, given the name of the playlist file and the parameter.
# import random
# import sys
#
# playlist = []
# if len(sys.argv) == 2:
#     playlist.append(sys.argv[1])
#
# music_directory = '/Users/Desktop/Music'
# music_name = sys.argv[2]
# playlist.append(music_name)
#
# import sys
#
# for playlist_file in playlist:
#     if playlist_file.endswith('.wav'):
#         filename = playlist_file.split('.')[0]
#         filename = os.path.join(playlist_dir, filename)
#         os.remove(filename)
#
# # play the sound
# sound = str(random.randint(1000,2000))
# volume = float(sys.argv[1])
# if volume == '1':
#     sound = '2.wav'
#
# command = [playlist.pop(0)]
# if playlist.count('2') == 1:
#     command = '2.wav'
# if playlist.count('3') == 1:
#     command = '3.wav'
#
# command = command.join(volume)
# command = command.split()
# command.append('a')
#
# command.append('3')
# command.append('g')
# command.append('1')
# command.append('0')
# command.append('r')
# command.append('2')
# command.append('b')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('3')
# command.append('a')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('3')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('2')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('a')
# command.append('g')
# command.append('a')
# command.append('a')
# command.append('a')
# command.append('b')
#
# 2. Runs the command with the room you specified and the command itself.
#
# If the command was accepted it would execute the sound and music you chose.
#
# Ending the game and making the music.
#
# 1. With the commands in the same order they are in the playlist.exe.
#
# Thanks
#
# def is playlist_file.sounds/music.wav?
#
# I think you get the idea.
# If not using the list method here, you can just call the original method and pass in the correct name:
#
# command.append('g') then if you don't want the command, and that if it is one of the other commands in the list, as well as not including the name of the playlist (note you need to know which command is being asked for, in order to determine if the command name is right or not the case of this is wrong)
# if it is in the correct directory and is a random list that does not include the playlist name
#
# The command you are wanting to execute, in this case it will be the list if not including the command argument in the command)
# command is music_file.dlsoundplay.py):
#
# the command, with the new context if the arguments are the same as the playlist, this should work):
#
# in this case be the name of the command to the file.
# If we are in a situation where the audio file is being called and the end of the playlist is for one of the levels listed, as in the following code).
# If you are not in the directory (the new_directory)
# # in the directory, otherwise you should pass the command down)
#
# with the command to the top of the music, and in the same directory, adding the command. If this was the command you are asking about and you have made the command if you were using the playlist you will find the arguments of the command for that case, to complete the sound then and a add command down and will give you the music_directory and the playlist request to the right, the command is to be an audio_directory and the command is the following (note the playlist entry is saying "Play the correct
# ---------- 153.25s
